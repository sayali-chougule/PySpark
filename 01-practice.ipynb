# %%
import pyspark
import pandas as pd
from pyspark.sql import SparkSession

# %%
pd.read_csv('BigMart_Sales.csv').head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()
spark.sparkContext.setLogLevel("ERROR")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/07/28 23:57:54 WARN Utils: Your hostname, Sayalis-MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.0.0.59 instead (on interface en0)
# 26/07/28 23:57:54 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/28 23:57:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.0.0.59:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Read the DataSet

# %%
df_pyspark = spark.read.csv('BigMart_Sales.csv')

# %%
df_pyspark.show()
# Out:
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+--------------------+-----------+--------------------+-----------------+-----------------+
# |            _c0|        _c1|             _c2|            _c3|                 _c4|     _c5|              _c6|                 _c7|        _c8|                 _c9|             _c10|             _c11|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+--------------------+-----------+--------------------+-----------------+-----------------+
# |Item_Identifier|Item_Weight|Item_Fat_Content|Item_Visibility|           Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishm...|Outlet_Size|Outlet_Location_Type|      Outlet_Type|Item_Outlet_Sales|
# ...

# %% [markdown]
# ### Rearranging Table Format

# %%
df_pyspark=spark.read.option('header', 'true').csv('BigMart_Sales.csv')

# %%
df_pyspark
# Out:
# DataFrame[Item_Identifier: string, Item_Weight: string, Item_Fat_Content: string, Item_Visibility: string, Item_Type: string, Item_MRP: string, Outlet_Identifier: string, Outlet_Establishment_Year: string, Outlet_Size: string, Outlet_Location_Type: string, Outlet_Type: string, Item_Outlet_Sales: string]

# %%
df_pyspark.show()
# Out:
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+
# |Item_Identifier|Item_Weight|Item_Fat_Content|Item_Visibility|           Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|Outlet_Size|Outlet_Location_Type|      Outlet_Type|Item_Outlet_Sales|
# +---------------+-----------+----------------+---------------+--------------------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+
# |          FDA15|        9.3|         Low Fat|    0.016047301|               Dairy|249.8092|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|         3735.138|
# ...

# %% [markdown]
# ### Checking Spark DataFrame Type

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %% [markdown]
# ### Check the Schema (Checking DataTypes Of Columns)

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Item_Identifier: string (nullable = true)
#  |-- Item_Weight: string (nullable = true)
#  |-- Item_Fat_Content: string (nullable = true)
#  |-- Item_Visibility: string (nullable = true)
#  |-- Item_Type: string (nullable = true)
#  |-- Item_MRP: string (nullable = true)
#  |-- Outlet_Identifier: string (nullable = true)
#  |-- Outlet_Establishment_Year: string (nullable = true)
#  |-- Outlet_Size: string (nullable = true)
#  |-- Outlet_Location_Type: string (nullable = true)
#  |-- Outlet_Type: string (nullable = true)
#  |-- Item_Outlet_Sales: string (nullable = true)

# %% [markdown]
# ### Selecting Columns and Indexing

# %%
df_pyspark.columns
# Out:
# ['Item_Identifier',
#  'Item_Weight',
#  'Item_Fat_Content',
#  'Item_Visibility',
#  'Item_Type',
#  'Item_MRP',
#  'Outlet_Identifier',
#  'Outlet_Establishment_Year',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'Item_Outlet_Sales']

# %%
df_pyspark.select('Item_Type').show(5)
# Out:
# +--------------------+
# |           Item_Type|
# +--------------------+
# |               Dairy|
# |         Soft Drinks|
# |                Meat|
# |Fruits and Vegeta...|
# |           Household|
# +--------------------+
# only showing top 5 rows

# %% [markdown]
# ### Selecting Multiple Columns

# %%
df_pyspark.select('Item_Type', 'Item_MRP').show(5)
# Out:
# +--------------------+--------+
# |           Item_Type|Item_MRP|
# +--------------------+--------+
# |               Dairy|249.8092|
# |         Soft Drinks| 48.2692|
# |                Meat| 141.618|
# |Fruits and Vegeta...| 182.095|
# |           Household| 53.8614|
# +--------------------+--------+
# only showing top 5 rows

# %%
df_pyspark.dtypes
# Out:
# [('Item_Identifier', 'string'),
#  ('Item_Weight', 'string'),
#  ('Item_Fat_Content', 'string'),
#  ('Item_Visibility', 'string'),
#  ('Item_Type', 'string'),
#  ('Item_MRP', 'string'),
#  ('Outlet_Identifier', 'string'),
#  ('Outlet_Establishment_Year', 'string'),
#  ('Outlet_Size', 'string'),
#  ('Outlet_Location_Type', 'string'),
#  ('Outlet_Type', 'string'),
#  ('Item_Outlet_Sales', 'string')]

# %% [markdown]
# ### Check Describe Option Similar to Pandas

# %%
df_pyspark.describe().show()
# Out:
# +-------+---------------+------------------+----------------+-------------------+-------------+-----------------+-----------------+-------------------------+-----------+--------------------+-----------------+------------------+
# |summary|Item_Identifier|       Item_Weight|Item_Fat_Content|    Item_Visibility|    Item_Type|         Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|Outlet_Size|Outlet_Location_Type|      Outlet_Type| Item_Outlet_Sales|
# +-------+---------------+------------------+----------------+-------------------+-------------+-----------------+-----------------+-------------------------+-----------+--------------------+-----------------+------------------+
# |  count|           8523|              7060|            8523|               8523|         8523|             8523|             8523|                     8523|       6113|                8523|             8523|              8523|
# ...

# %% [markdown]
# ### Adding Columns in PySpark DataFrame

# %%
df_pyspark = df_pyspark.withColumn('ID', df_pyspark['Item_Identifier'])

# %%
df_pyspark.show(3)
# Out:
# +---------------+-----------+----------------+---------------+-----------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+-----+
# |Item_Identifier|Item_Weight|Item_Fat_Content|Item_Visibility|  Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|Outlet_Size|Outlet_Location_Type|      Outlet_Type|Item_Outlet_Sales|   ID|
# +---------------+-----------+----------------+---------------+-----------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+-----+
# |          FDA15|        9.3|         Low Fat|    0.016047301|      Dairy|249.8092|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|         3735.138|FDA15|
# ...

# %% [markdown]
# ###

# %% [markdown]
# ### Drop The Column

# %%
df_pyspark = df_pyspark.drop('Item_Identifier')

# %%
df_pyspark.show(3)
# Out:
# +-----------+----------------+---------------+-----------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+-----+
# |Item_Weight|Item_Fat_Content|Item_Visibility|  Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|Outlet_Size|Outlet_Location_Type|      Outlet_Type|Item_Outlet_Sales|   ID|
# +-----------+----------------+---------------+-----------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+-----+
# |        9.3|         Low Fat|    0.016047301|      Dairy|249.8092|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|         3735.138|FDA15|
# |       5.92|         Regular|    0.019278216|Soft Drinks| 48.2692|           OUT018|                     2009|     Medium|              Tier 3|Supermarket Type2|         443.4228|DRC01|
# ...

# %% [markdown]
# ### Rename Column

# %%
df_pyspark = df_pyspark.withColumnRenamed('Weight', 'Item_Weight')

# %%
df_pyspark.show(3)
# Out:
# +-----------+----------------+---------------+-----------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+-----+
# |Item_Weight|Item_Fat_Content|Item_Visibility|  Item_Type|Item_MRP|Outlet_Identifier|Outlet_Establishment_Year|Outlet_Size|Outlet_Location_Type|      Outlet_Type|Item_Outlet_Sales|   ID|
# +-----------+----------------+---------------+-----------+--------+-----------------+-------------------------+-----------+--------------------+-----------------+-----------------+-----+
# |        9.3|         Low Fat|    0.016047301|      Dairy|249.8092|           OUT049|                     1999|     Medium|              Tier 1|Supermarket Type1|         3735.138|FDA15|
# |       5.92|         Regular|    0.019278216|Soft Drinks| 48.2692|           OUT018|                     2009|     Medium|              Tier 3|Supermarket Type2|         443.4228|DRC01|
# ...
